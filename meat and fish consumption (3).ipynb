# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv("Consumption of meat per capita.csv")

# %%
# data exploration
# step 1: inspect dataset
(dataset.head())
# Out:
#         Entity  Year   Poultry      Beef  Sheep and goat  Pork  Other meats  \
# 0  Afghanistan  1961  0.641744  4.889479        8.332486   NaN     0.865845
# 1  Afghanistan  1962  0.672726  5.106605        8.072717   NaN     0.896969
# 2  Afghanistan  1963  0.673156  5.160862        8.251259   NaN     1.091328
# 3  Afghanistan  1964  0.683714  5.132955        8.520909   NaN     1.030673
# 4  Afghanistan  1965  0.714625  5.094256        8.820517   NaN     1.082147
#
#    Fish and seafood
# 0          0.030559
# 1          0.030578
# 2          0.030598
# 3          0.030614
# 4          0.030627

# %%
# step 2: inspect dataset
(dataset.tail())
# Out:
#          Entity  Year   Poultry       Beef  Sheep and goat  Pork  Other meats  \
# 10075  Zimbabwe  2017  5.090000  41.409996        1.810000  0.74     2.500000
# 10076  Zimbabwe  2018  4.379997  40.989970        1.819999  0.52     2.389998
# 10077  Zimbabwe  2019  4.470001  40.980010        1.770001  0.69     2.370001
# 10078  Zimbabwe  2020  7.210003  40.120018        1.760001  0.64     2.270001
# 10079  Zimbabwe  2021  7.329998  43.769985        1.909999  0.73     2.229999
#
#        Fish and seafood
# 10075          3.930000
# 10076          3.119998
# 10077          2.020001
# 10078          1.980001
# 10079          1.939999

# %%
# step 3: display dataset summary
(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10080 entries, 0 to 10079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Entity            10080 non-null  object
#  1   Year              10080 non-null  int64
#  2   Poultry           10080 non-null  float64
#  3   Beef              10079 non-null  float64
#  4   Sheep and goat    10080 non-null  float64
#  5   Pork              9792 non-null   float64
#  6   Other meats       10073 non-null  float64
#  7   Fish and seafood  10080 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 630.1+ KB

# %%
# step 4: displaybasic statistics
(dataset.describe())
# Out:
#                Year       Poultry          Beef  Sheep and goat         Pork  \
# count  10080.000000  10080.000000  10079.000000    10080.000000  9792.000000
# mean    1992.238492     12.545315     11.861681        3.455898    11.687291
# std       17.664153     13.795981     11.281156        6.570487    14.451765
# min     1961.000000      0.000000      0.000000        0.000000     0.000000
# 25%     1977.000000      1.985262      4.250644        0.471978     1.063430
# 50%     1993.000000      7.303228      8.111460        1.243124     5.348965
# 75%     2008.000000     18.781992     16.737870        3.740079    17.406121
# max     2021.000000     89.530410     92.688950       66.910000    78.026120
#
#         Other meats  Fish and seafood
# count  10073.000000      10080.000000
# mean       1.864093         16.768571
# std        4.600452         17.234011
# min        0.000000          0.000000
# 25%        0.099981          5.009638
# 50%        0.677016         11.850100
# 75%        1.771093         23.257070
# max       70.123795        183.213730

# %%
# step 5: check missing values
missing_values = dataset.isnull().sum()
print("\nmissing_values in each column:")
print(missing_values)
# Out:
# missing_values in each column:
# Entity                0
# Year                  0
# Poultry               0
# Beef                  1
# Sheep and goat        0
# Pork                288
# Other meats           7
# Fish and seafood      0
# dtype: int64

# %%
# Step 6: replace missing values
dataset["Beef"] = dataset["Beef"].fillna(dataset["Beef"].mean())
dataset["Pork"] = dataset["Pork"].fillna(dataset["Pork"].mean())
dataset["Other meats"] = dataset["Other meats"].fillna(dataset["Other meats"].mean())

# %%
# Step 7: Check replaced misssing values
print("\ndataset after replacing missing values:")
print(dataset)
# Out:
# dataset after replacing missing values:
#             Entity  Year   Poultry       Beef  Sheep and goat       Pork  \
# 0      Afghanistan  1961  0.641744   4.889479        8.332486  11.687291
# 1      Afghanistan  1962  0.672726   5.106605        8.072717  11.687291
# 2      Afghanistan  1963  0.673156   5.160862        8.251259  11.687291
# 3      Afghanistan  1964  0.683714   5.132955        8.520909  11.687291
# 4      Afghanistan  1965  0.714625   5.094256        8.820517  11.687291
# ...            ...   ...       ...        ...             ...        ...
# 10075     Zimbabwe  2017  5.090000  41.409996        1.810000   0.740000
# 10076     Zimbabwe  2018  4.379997  40.989970        1.819999   0.520000
# 10077     Zimbabwe  2019  4.470001  40.980010        1.770001   0.690000
# 10078     Zimbabwe  2020  7.210003  40.120018        1.760001   0.640000
# 10079     Zimbabwe  2021  7.329998  43.769985        1.909999   0.730000
#
#        Other meats  Fish and seafood
# 0         0.865845          0.030559
# 1         0.896969          0.030578
# 2         1.091328          0.030598
# 3         1.030673          0.030614
# 4         1.082147          0.030627
# ...            ...               ...
# 10075     2.500000          3.930000
# 10076     2.389998          3.119998
# 10077     2.370001          2.020001
# 10078     2.270001          1.980001
# 10079     2.229999          1.939999
#
# [10080 rows x 8 columns]

# %%
#step 8:Entity with highest consumption
highest_consumption = dataset.set_index("Entity")
print(highest_consumption)
# Out:
#              Year   Poultry       Beef  Sheep and goat       Pork  \
# Entity
# Afghanistan  1961  0.641744   4.889479        8.332486  11.687291
# Afghanistan  1962  0.672726   5.106605        8.072717  11.687291
# Afghanistan  1963  0.673156   5.160862        8.251259  11.687291
# Afghanistan  1964  0.683714   5.132955        8.520909  11.687291
# Afghanistan  1965  0.714625   5.094256        8.820517  11.687291
# ...           ...       ...        ...             ...        ...
# Zimbabwe     2017  5.090000  41.409996        1.810000   0.740000
# Zimbabwe     2018  4.379997  40.989970        1.819999   0.520000
# Zimbabwe     2019  4.470001  40.980010        1.770001   0.690000
# Zimbabwe     2020  7.210003  40.120018        1.760001   0.640000
# Zimbabwe     2021  7.329998  43.769985        1.909999   0.730000
#
#              Other meats  Fish and seafood
# Entity
# Afghanistan     0.865845          0.030559
# Afghanistan     0.896969          0.030578
# Afghanistan     1.091328          0.030598
# Afghanistan     1.030673          0.030614
# Afghanistan     1.082147          0.030627
# ...                  ...               ...
# Zimbabwe        2.500000          3.930000
# Zimbabwe        2.389998          3.119998
# Zimbabwe        2.370001          2.020001
# Zimbabwe        2.270001          1.980001
# Zimbabwe        2.229999          1.939999
#
# [10080 rows x 7 columns]

# %%
# Step 9: year with hisghest consuption
Highest_Consumption_Year = dataset.set_index("Year").idxmax()
print(Highest_Consumption_Year)
# Out:
# Entity              1961
# Poultry             2009
# Beef                1976
# Sheep and goat      2020
# Pork                1989
# Other meats         1964
# Fish and seafood    2002
# dtype: int64

# %%
# Step 10
# Year_group
bins = [1960, 1980, 2000, 2021]
labels = ["1960-1980", "1981-2000", "2001-2021"]
dataset["Year_group"] = pd.cut(dataset["Year"], bins=bins, labels=labels, right=True)
dataset.head(40)
# Out:
#          Entity  Year   Poultry      Beef  Sheep and goat       Pork  \
# 0   Afghanistan  1961  0.641744  4.889479        8.332486  11.687291
# 1   Afghanistan  1962  0.672726  5.106605        8.072717  11.687291
# 2   Afghanistan  1963  0.673156  5.160862        8.251259  11.687291
# 3   Afghanistan  1964  0.683714  5.132955        8.520909  11.687291
# 4   Afghanistan  1965  0.714625  5.094256        8.820517  11.687291
# 5   Afghanistan  1966  0.735223  6.953985        9.169866  11.687291
# 6   Afghanistan  1967  0.755670  6.494673       10.017728  11.687291
# 7   Afghanistan  1968  0.776184  6.924375       10.866570  11.687291
# 8   Afghanistan  1969  0.909888  7.146198       10.131448  11.687291
# 9   Afghanistan  1970  0.891281  5.767715        9.875803  11.687291
# 10  Afghanistan  1971  0.873700  5.632795        9.744324  11.687291
# 11  Afghanistan  1972  0.845955  5.405856        7.799288  11.687291
# 12  Afghanistan  1973  0.868352  5.437537        8.600818  11.687291
# 13  Afghanistan  1974  0.837577  5.221932        8.975517  11.687291
# 14  Afghanistan  1975  0.856940  5.017748        9.333425  11.687291
# 15  Afghanistan  1976  0.834884  5.009307       10.987492  11.687291
# 16  Afghanistan  1977  0.852680  5.198269       10.817741  11.687291
# 17  Afghanistan  1978  0.867155  5.182526       10.915951  11.687291
# 18  Afghanistan  1979  0.928963  5.471697       10.626933  11.687291
# 19  Afghanistan  1980  0.960531  5.362083       11.684696  11.687291
# 20  Afghanistan  1981  1.115663  6.101282       13.666873  11.687291
# 21  Afghanistan  1982  1.227296  6.837793       15.291109  11.687291
# 22  Afghanistan  1983  1.267078  6.827460       14.516040  11.687291
# 23  Afghanistan  1984  1.319208  6.642330       13.053219  11.687291
# 24  Afghanistan  1985  1.294134  6.470669       11.230450  11.687291
# 25  Afghanistan  1986  1.412001  6.510296       10.207368  11.687291
# 26  Afghanistan  1987  1.457524  6.837502       11.017166  11.687291
# 27  Afghanistan  1988  1.251542  6.894090       11.635103  11.687291
# 28  Afghanistan  1989  1.208380  6.724899       11.989233  11.687291
# 29  Afghanistan  1990  1.162701  8.095032       12.625178  11.687291
# 30  Afghanistan  1991  1.138525  8.051835       12.781995  11.687291
# 31  Afghanistan  1992  1.053876  7.170937       11.031330  11.687291
# 32  Afghanistan  1993  0.845237  6.946115        9.395135  11.687291
# 33  Afghanistan  1994  0.757291  7.338253        8.682177  11.687291
# 34  Afghanistan  1995  0.760468  7.915296        8.140223  11.687291
# 35  Afghanistan  1996  0.764304  8.364289        8.461173  11.687291
# 36  Afghanistan  1997  0.791258  8.767991        8.971152  11.687291
# 37  Afghanistan  1998  0.811798  9.246064        9.414749  11.687291
# 38  Afghanistan  1999  0.726315  7.730067        9.971267  11.687291
# 39  Afghanistan  2000  0.674452  6.449444        8.683565  11.687291
#
#     Other meats  Fish and seafood Year_group
# 0      0.865845          0.030559  1960-1980
# 1      0.896969          0.030578  1960-1980
# 2      1.091328          0.030598  1960-1980
# 3      1.030673          0.030614  1960-1980
# 4      1.082147          0.030627  1960-1980
# 5      1.051778          0.030634  1960-1980
# 6      1.133504          0.040847  1960-1980
# 7      1.102998          0.040852  1960-1980
# 8      1.083687          0.040894  1960-1980
# 9      1.055195          0.040978  1960-1980
# 10     1.120392          0.051394  1960-1980
# 11     1.093551          0.051583  1960-1980
# 12     1.085440          0.051688  1960-1980
# 13     1.075408          0.051702  1960-1980
# 14     1.073757          0.051623  1960-1980
# 15     1.061643          0.061843  1960-1980
# 16     1.181425          0.061640  1960-1980
# 17     1.163008          0.061211  1960-1980
# 18     1.051464          0.061250  1960-1980
# 19     1.108305          0.073887  1960-1980
# 20     1.208635          0.081350  1981-2000
# 21     1.302437          0.087664  1981-2000
# 22     1.279380          0.098414  1981-2000
# 23     1.157200          0.092576  1981-2000
# 24     0.976084          0.087738  1981-2000
# 25     0.743726          0.097008  1981-2000
# 26     0.760913          0.117888  1981-2000
# 27     0.869716          0.116669  1981-2000
# 28     0.945689          0.105077  1981-2000
# 29     1.053012          0.131627  1981-2000
# 30     1.079838          0.129111  1981-2000
# 31     1.145517          0.126007  1981-2000
# 32     1.061964          0.108364  1981-2000
# 33     0.885283          0.106661  1981-2000
# 34     0.781890          0.096397  1981-2000
# 35     0.538243          0.096884  1981-2000
# 36     0.556019          0.085541  1981-2000
# 37     0.548227          0.084343  1981-2000
# 38     0.539548          0.083007  1981-2000
# 39     0.526915          0.063230  1981-2000

# %%
bins = [1961, 1980, 2000, 2021]
labels = ["1961-1980", "1981-2000", "2001-2021"]
dataset["Year_group"] = pd.cut(dataset["Year"], bins=bins, labels=labels, right=True)
dataset.tail(40)
# Out:
#          Entity  Year   Poultry       Beef  Sheep and goat      Pork  \
# 10040  Zimbabwe  1982  1.140590   9.013691        0.504686  1.322277
# 10041  Zimbabwe  1983  1.183227   7.382525        0.556218  1.415827
# 10042  Zimbabwe  1984  1.076335   6.407240        0.741250  1.066181
# 10043  Zimbabwe  1985  1.060282   6.433059        0.744237  0.927747
# 10044  Zimbabwe  1986  1.054188   7.635186        0.859726  0.941605
# 10045  Zimbabwe  1987  1.263081   6.520782        0.944743  1.088508
# 10046  Zimbabwe  1988  1.431437   6.333338        0.947426  1.101898
# 10047  Zimbabwe  1989  1.590150   6.670371        1.011914  1.146147
# 10048  Zimbabwe  1990  1.655069   7.416778        1.086139  1.106827
# 10049  Zimbabwe  1991  1.665103   7.260261        1.065252  1.044568
# 10050  Zimbabwe  1992  1.578812   7.099493        1.052541  1.021584
# 10051  Zimbabwe  1993  1.568201   4.330729        0.986617  0.716595
# 10052  Zimbabwe  1994  1.494592   4.536404        1.020954  0.842024
# 10053  Zimbabwe  1995  1.651516   4.626362        1.026904  1.005731
# 10054  Zimbabwe  1996  1.843955   4.864225        1.091536  0.900782
# 10055  Zimbabwe  1997  1.918894   5.353822        1.060163  0.943545
# 10056  Zimbabwe  1998  1.959195   5.125678        1.080205  0.974302
# 10057  Zimbabwe  1999  1.923850   6.543205        1.152196  1.004208
# 10058  Zimbabwe  2000  2.060284   7.121187        1.172777  1.584834
# 10059  Zimbabwe  2001  3.191403   9.045832        1.162432  2.335431
# 10060  Zimbabwe  2002  2.721297   7.552128        1.307910  2.193914
# 10061  Zimbabwe  2003  3.347749   7.755445        1.259341  2.224837
# 10062  Zimbabwe  2004  3.788835   8.412676        1.179445  2.212763
# 10063  Zimbabwe  2005  4.211090   8.349395        1.216537  2.256312
# 10064  Zimbabwe  2006  4.364994   8.420415        1.155743  2.259891
# 10065  Zimbabwe  2007  4.594377   8.370158        1.217664  2.251143
# 10066  Zimbabwe  2008  4.919919   8.291541        1.130665  2.240957
# 10067  Zimbabwe  2009  6.149811   8.243796        1.046993  2.571739
# 10068  Zimbabwe  2010  6.189998  50.539980        1.909999  1.709999
# 10069  Zimbabwe  2011  6.859995  52.639965        1.899999  1.989999
# 10070  Zimbabwe  2012  6.949999  52.599995        1.940000  2.090000
# 10071  Zimbabwe  2013  5.190000  51.520000        1.940000  1.970000
# 10072  Zimbabwe  2014  4.719997  39.939976        1.929999  2.039999
# 10073  Zimbabwe  2015  4.880001  44.060013        1.780000  1.670000
# 10074  Zimbabwe  2016  5.169998  43.699986        1.440000  1.570000
# 10075  Zimbabwe  2017  5.090000  41.409996        1.810000  0.740000
# 10076  Zimbabwe  2018  4.379997  40.989970        1.819999  0.520000
# 10077  Zimbabwe  2019  4.470001  40.980010        1.770001  0.690000
# 10078  Zimbabwe  2020  7.210003  40.120018        1.760001  0.640000
# 10079  Zimbabwe  2021  7.329998  43.769985        1.909999  0.730000
#
#        Other meats  Fish and seafood Year_group
# 10040     1.857244          2.543617  1981-2000
# 10041     1.840575          1.901253  1981-2000
# 10042     1.817585          2.030821  1981-2000
# 10043     1.824909          2.018614  1981-2000
# 10044     1.852505          2.200489  1981-2000
# 10045     1.838142          2.166748  1981-2000
# 10046     1.833064          2.358267  1981-2000
# 10047     1.827640          2.478157  1981-2000
# 10048     1.830920          2.565357  1981-2000
# 10049     1.830579          2.161531  1981-2000
# 10050     1.403388          2.228911  1981-2000
# 10051     1.672056          3.042934  1981-2000
# 10052     1.799826          3.536501  1981-2000
# 10053     1.958529          3.514765  1981-2000
# 10054     2.066501          3.465363  1981-2000
# 10055     2.024911          3.254700  1981-2000
# 10056     2.075688          2.541659  1981-2000
# 10057     2.135263          2.166974  1981-2000
# 10058     2.187071          2.165940  1981-2000
# 10059     2.272025          1.511161  2001-2021
# 10060     2.331034          1.318458  2001-2021
# 10061     2.445221          1.164891  2001-2021
# 10062     2.672016          1.503009  2001-2021
# 10063     2.651427          1.102162  2001-2021
# 10064     2.703613          1.393083  2001-2021
# 10065     2.691139          1.125571  2001-2021
# 10066     2.699335          1.171409  2001-2021
# 10067     2.897018          1.382437  2001-2021
# 10068     2.339999          2.329999  2001-2021
# 10069     2.389998          3.179998  2001-2021
# 10070     2.330000          3.240000  2001-2021
# 10071     2.430000          3.830000  2001-2021
# 10072     2.629999          3.819998  2001-2021
# 10073     2.650001          4.370001  2001-2021
# 10074     2.609999          4.309998  2001-2021
# 10075     2.500000          3.930000  2001-2021
# 10076     2.389998          3.119998  2001-2021
# 10077     2.370001          2.020001  2001-2021
# 10078     2.270001          1.980001  2001-2021
# 10079     2.229999          1.939999  2001-2021

# %%
# Step 11
# Count by Year_group
sns.countplot(x=dataset.Year_group)
plt.show()

# %%
# Step 12: Bar chart plot by Year_group and individual meat consumption
plt.figure(figsize=(8, 5))
sns.barplot(x="Year_group", y="Pork", hue="Year_group", data=dataset)
plt.xlabel("Year_group")
plt.ylabel("Pork")
plt.title("Grouped by Pork")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="Year_group", y="Poultry", hue="Year_group", data=dataset)
plt.xlabel("Year_group")
plt.ylabel("Poultry")
plt.title("Grouped by Poultry")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="Year_group", y="Beef", hue="Year_group", data=dataset)
plt.xlabel("Year_group")
plt.ylabel("Beef")
plt.title("Grouped by Beef")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x="Year_group", y="Sheep and goat", hue="Year_group", data=dataset)
plt.xlabel("Year_group")
plt.ylabel("Sheep and goat")
plt.title("Grouped by Sheep and goat")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x="Year_group", y="Other meats", hue="Year_group", data=dataset)
plt.xlabel("Year_group")
plt.ylabel("Other meats")
plt.title("Grouped by Other meats")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x="Year_group", y="Fish and seafood", hue="Year_group", data=dataset)
plt.xlabel("Year_group")
plt.ylabel("Fish and seafood")
plt.title("Grouped by fish and seafood")
plt.show()

# %%
# Step 13
# highest consumption by Entity
Highest_Consumption_Entity = dataset.set_index("Entity").idxmax()
print(Highest_Consumption_Entity)
# Out:
# Year                Afghanistan
# Poultry                  Kuwait
# Beef                New Zealand
# Sheep and goat         Mongolia
# Pork                    Hungary
# Other meats          East Timor
# Fish and seafood       Maldives
# Year_group          Afghanistan
# dtype: object

# %%
# Step 14
#  category count
print(dataset["Entity"].value_counts())
# Out:
# Entity
# Afghanistan    61
# Mauritius      61
# Mongolia       61
# Morocco        61
# Mozambique     61
#                ..
# Bahrain         3
# Bhutan          3
# South Sudan     3
# Qatar           3
# Nauru           3
# Name: count, Length: 195, dtype: int64

# %%
# Step 15
# Groupby Entity
dataset.groupby("Entity").idxmax()
# Out:
#                       Year  Poultry   Beef  Sheep and goat   Pork  \
# Entity
# Afghanistan             60       49     37              21      0
# Albania                121      121    108             109    107
# Algeria                182      165    165             182    122
# Angola                 243      236    204             230    236
# Antigua and Barbuda    304      293    271             290    263
# ...                    ...      ...    ...             ...    ...
# World                 9865     9865   9820            9865   9860
# Yemen                 9926     9919   9915            9919   9868
# Yugoslavia            9957     9953   9956            9954   9956
# Zambia               10018     9973  10010           10018  10009
# Zimbabwe             10079    10079  10069           10071  10067
#
#                      Other meats  Fish and seafood  Year_group
# Entity
# Afghanistan                   21                56          40
# Albania                      119               118         101
# Algeria                      140               168         162
# Angola                       189               236         223
# Antigua and Barbuda          288               291         284
# ...                          ...               ...         ...
# World                       9805              9863        9845
# Yemen                       9882              9909        9906
# Yugoslavia                  9956              9956        9947
# Zambia                      9965              9967        9998
# Zimbabwe                   10067             10073       10059
#
# [195 rows x 8 columns]

# %%
# Step 16
# Exporting of cleaned data
dataset.to_csv("claened_meat_consumption_per_capita_data.csv", index=False)
